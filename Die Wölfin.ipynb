# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Erstellung des Nivesenstammes: Insgesamt 139 in jeweils 5 Personen-Zelten und simulieren bis alle Nivesen erkrankt sind:

# %%
from plots import plot_symptome, plot_altersvert, plot_ansteckung
df = pd.read_csv('alle_nivesen.csv', sep=';')
plot_symptome(df)
plot_altersverteilung(df)
